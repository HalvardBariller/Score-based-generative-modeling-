# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt


local_path = '/Users/halvardbariller/Desktop/M2_MVA/_SEMESTER_1/PGM/Project/Score-matching-project-'
sys.path.append(local_path)

# %load_ext autoreload
# %autoreload 2

import dataset
from dataset import sampling, densities, scores, visualisation

# %% [markdown]
# # GMM

# %%
# Parameters
N = 10000
mus = [np.array([0, 0]), np.array([10,10])]
sigmas = [np.eye(2), np.eye(2)]
alphas = [0.5, 0.5]

# %%
data, clusters = sampling.gaussian_mixture_sampling(mus, sigmas, alphas, N)

# %%
visualisation.plot_GMM(data, clusters, mus, sigmas, alphas)

# %%
visualisation.gmm_density_heatmap(densities.gmm_density, mus, sigmas, alphas)

# %%
visualisation.gmm_score_plot(data=data, clusters=clusters, mus=mus, sigmas=sigmas, alphas=alphas)

# %% [markdown]
# # Banana-shaped data

# %%
# Parameters
N = 10000
mu = np.array([0, 0])
sigma = np.eye(2)

# %%
banana_data = sampling.banana_shaped_sampling(N, mu, sigma)

visualisation.plot_banana(banana_data)

# %%
visualisation.banana_score_plot(banana_data)
